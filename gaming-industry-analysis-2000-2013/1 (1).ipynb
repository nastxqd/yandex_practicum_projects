# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b></b></font>
#     <font size="4", color = "black">
#
# **Привет, Денис :)**
#
# Спасибо, что прислал задание 🤝
#
# Меня зовут Ринат Хисамов и я буду проверять твой проект. Предлагаю обращаться друг к другу на ты. Так нам будет гораздо проще и удобней общаться. Моя цель не указать на совершённые ошибки, а поделиться своим опытом и помочь улучшить навыки. При проверке работы я буду отмечать комментарии следующими символами:
#
# + ❌ - комментарии нужно исправить, чтобы проект был принят
# + 💡 - такой комментарий является рекомендацией или советом
# + ✅ - все остальные комментарии, включая позитивные моменты, пояснения и рассуждения✍
# + 🍕 - а это про «плюшки» и улучшения читаемости/красоты кода
#
# Увидев неточность, в первый раз я лишь укажу на неё — попробуй исправить самостоятельно. Если потребуется помощь — при следующей проверке дам более подробную подсказку!
#
# Поехали 🚀

# %% [markdown]
# # Развитие игровой индустрии с 2000 по 2013 год
#
# - Автор: Еренков Денис
# - Дата: 11.05.26

# %% [markdown]
# ### Цели и задачи проекта
#
# Провести комплексный анализ исторических данных игровой индустрии за период 2000–2013 годов, чтобы через призму ностальгии и цифровых трендов прошлого раскрыть эволюцию RPG-жанра, вдохновить поклонников классики и мягко погрузить их в атмосферу нового проекта — «Секреты Темнолесья»

# %% [markdown]
# # Описание данных
#
# Данные `/datasets/new_games.csv` содержат информацию о продажах игр разных жанров и платформ, а также пользовательские и экспертные оценки игр:
# - Name — название игры.
# - Platform — название платформы.
# - Year of Release — год выпуска игры.
# - Genre — жанр игры.
# - NA sales — продажи в Северной Америке (в миллионах проданных копий).
# - EU sales — продажи в Европе (в миллионах проданных копий).
# - JP sales — продажи в Японии (в миллионах проданных копий).
# - Other sales — продажи в других странах (в миллионах проданных копий).
# - Critic Score — оценка критиков (от 0 до 100).
# - User Score — оценка пользователей (от 0 до 10).
# - Rating — рейтинг организации ESRB (англ. Entertainment Software Rating Board). Эта ассоциация определяет рейтинг компьютерных игр и присваивает им подходящую возрастную категорию..</font>

# %% [markdown]
# ### Содержимое проекта
#
# - 1. Загрузка данных и знакомство с ними
# - 2. Проверка ошибок в данных и их предобработка
#    - 2.1 Названия, или метки, столбцов датафрейма
#    - 2.2 Типы данных
#    - 2.3 Наличие пропусков в данных
#    - 2.4 Явные и неявные дубликаты в данных
# - 3. Фильтрация данных
# - 4. Категоризация данных
# - 5. Итоговый вывод
#
# ---

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера </b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Название проекта добавлено. План проекта расписан довольно подробно, молодец — с планом тебе будет легче контроллировать процесс выполнения и финализации  решения

# %% [markdown]
# ## 1. Загрузка данных и знакомство с ними
#
# - Загрузите необходимые библиотеки Python и данные датасета `/datasets/new_games.csv`.

# %%
import pandas as pd
import re

# %%
df = pd.read_csv('https://code.s3.yandex.net/datasets/new_games.csv')

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>💡 Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Cтоит делить блок загрузки библиотек и код загрузки датасета.
#
# В случае необходимости добавления новых библиотек не придется загружать весь датасет заново и перезапускать проект целиком

# %% [markdown]
# <div class="alert" style="background-color: #d1ecf1; border-color: #bee5eb; border-radius: 8px; padding: 15px;">
#     <font size="3" color="black">
#         Исправлено
# </div>

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера </b></font>
# <br />
# <font size="3", color = "black">
# <br />   Кажется, весь код на проекте запускался вручную ... 19-я строка кода в начале проекта
#
# ![image-5.png](attachment:image-5.png)
#
#
# ![image-3.png](attachment:image-3.png)
#
#
# **Проверить работоспособность кода или перезапустить весь код заново — можно нажав на панели Jupiter Hub Kernel и Restart & Run All (см скриншот ниже) — это позволит быстро найти все опечатки в коде на проекте**
#
# ![image-2.png](attachment:image-2.png)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16956 entries, 0 to 16955
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16954 non-null  object
#  1   Platform         16956 non-null  object
#  2   Year of Release  16681 non-null  float64
#  3   Genre            16954 non-null  object
#  4   NA sales         16956 non-null  float64
#  5   EU sales         16956 non-null  object
#  6   JP sales         16956 non-null  object
#  7   Other sales      16956 non-null  float64
#  8   Critic Score     8242 non-null   float64
#  9   User Score       10152 non-null  object
#  10  Rating           10085 non-null  object
# dtypes: float64(4), object(7)
# memory usage: 1.4+ MB

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4"><b>🍕 Комментарий ревьюера</b></font>
#     <br />
#         <font size="3", color = "black">
#             <br />
#
# Совет по оформлению: display() вместо print() — показывает DataFrame сразу в красивом табличном виде
#
#
# В твоем случае можно полностью без print() и без display() по двум причинам:
#
# + если выражение (или переменная) — последнее в ячейке, Jupyter автоматически выведет её значение на экран, кроме случаев, когда выражение является присваиванием (например, df = data)
# + у метода .info() нет возвращаемого значения (он выводит информацию напрямую в консоль), поэтому его результат всё равно появится на экране независимо от print() или display()

# %% [markdown]
# <div class="alert" style="background-color: #d1ecf1; border-color: #bee5eb; border-radius: 8px; padding: 15px;">
#     <font size="3" color="black">
#         Исправлено
# </div>

# %%
df.head(15)
# Out:
#                            Name Platform  Year of Release         Genre  \
# 0                    Wii Sports      Wii           2006.0        Sports
# 1             Super Mario Bros.      NES           1985.0      Platform
# 2                Mario Kart Wii      Wii           2008.0        Racing
# 3             Wii Sports Resort      Wii           2009.0        Sports
# 4      Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# 5                        Tetris       GB           1989.0        Puzzle
# 6         New Super Mario Bros.       DS           2006.0      Platform
# 7                      Wii Play      Wii           2006.0          Misc
# 8     New Super Mario Bros. Wii      Wii           2009.0      Platform
# 9                     Duck Hunt      NES           1984.0       Shooter
# 10                   Nintendogs       DS           2005.0    Simulation
# 11                Mario Kart DS       DS           2005.0        Racing
# ...

# %%
df.nunique()
# Out:
# Name               11559
# Platform              31
# Year of Release       37
# Genre                 24
# NA sales             402
# EU sales             308
# JP sales             245
# Other sales          155
# Critic Score          82
# User Score            96
# Rating                 8
# dtype: int64

# %%
df.tail()
# Out:
#                                 Name Platform  Year of Release       Genre  \
# 16951  Samurai Warriors: Sanada Maru      PS3           2016.0      Action
# 16952               LMA Manager 2007     X360           2006.0      Sports
# 16953        Haitaka no Psychedelica      PSV           2016.0   Adventure
# 16954               Spirits & Spells      GBA           2003.0    Platform
# 16955            Winning Post 8 2016      PSV           2016.0  Simulation
#
#        NA sales EU sales JP sales  Other sales  Critic Score User Score Rating
# 16951      0.00      0.0     0.01          0.0           NaN        NaN    NaN
# 16952      0.00     0.01      0.0          0.0           NaN        NaN    NaN
# 16953      0.00      0.0     0.01          0.0           NaN        NaN    NaN
# 16954      0.01      0.0      0.0          0.0           NaN        NaN    NaN
# 16955      0.00      0.0     0.01          0.0           NaN        NaN    NaN

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4"><b>🍕 Комментарий ревьюера</b></font>
#     <br />
#         <font size="3", color = "black">
#             <br />
# Подсвечу, что для знакомства с данными можно использовать и такие методы .tail(), .sample()

# %% [markdown]
# Резюме по выведенным данным: Предоставленный набор данных включает 16 956 строк, охватывая богатую историю игровой индустрии. Информация структурирована в 11 столбцах, однако в 6 из
# них присутствуют пропущенные значения — особенно заметная нехватка данных наблюдается в полях `Critic Score`, `User Score` и `Rating`, что может повлиять на глубину анализа восприятия игр сообществом и рейтинговой оценки.
#
# Названия столбцов в целом логичны и соответствуют содержанию, однако их оформление нарушает стандарты чистоты данных: используются пробелы вместо подчёркиваний, что усложняет программную обработку.
#
# Особое внимание требует типизация данных:
#
# - `EU Sales` и `JP Sales`, содержащие числовые значения продаж, ошибочно определены как object вместо float64.
#
# - `User Score` — также в формате object, хотя по смыслу является числом с плавающей точкой.
#
# - `Year of Release` представлен как float, тогда как год логичнее и корректнее хранить как целое число (int64).

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Корректно загрузил датасет, детально исследовал первичные признаки, нашел несоответствия описанию, оценил масштаб проблемы с пропусками, указал причины некорректных типов, предложил направления для предобработкии и сформировал вывод для первого раздела
#
# Такой вывод приятно читать. Он показывает, что ты не просто «прошел этап», а действительно вник в данные и готов к осознанной предобработке. Продолжай в том же духе!

# %% [markdown]
# ---
#
# ## 2.  Проверка ошибок в данных и их предобработка
#
#
# ### 2.1. Названия, или метки, столбцов датафрейма
#
# - Выведите на экран названия всех столбцов датафрейма и проверьте их стиль написания.
# - Приведите все столбцы к стилю snake case. Названия должны быть в нижнем регистре, а вместо пробелов — подчёркивания.

# %%
df.columns.tolist()
# Out:
# ['Name',
#  'Platform',
#  'Year of Release',
#  'Genre',
#  'NA sales',
#  'EU sales',
#  'JP sales',
#  'Other sales',
#  'Critic Score',
#  'User Score',
#  'Rating']

# %%
df.columns = df.columns.str.lower().str.replace(' ', '_')
df.columns
# Out:
# Index(['name', 'platform', 'year_of_release', 'genre', 'na_sales', 'eu_sales',
#        'jp_sales', 'other_sales', 'critic_score', 'user_score', 'rating'],
#       dtype='object')

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# Названия колонок преобразованы к нотации `snake_case` корректно, плюс эффективно используешь цепочку методов, молодец!

# %% [markdown]
# ### 2.2. Типы данных

# %%
df.dtypes
# Out:
# name                object
# platform            object
# year_of_release    float64
# genre               object
# na_sales           float64
# eu_sales            object
# jp_sales            object
# other_sales        float64
# critic_score       float64
# user_score          object
# rating              object
# dtype: object

# %%
df.nunique()
# Out:
# name               11559
# platform              31
# year_of_release       37
# genre                 24
# na_sales             402
# eu_sales             308
# jp_sales             245
# other_sales          155
# critic_score          82
# user_score            96
# rating                 8
# dtype: int64

# %% [markdown]
# Проверка диапазона годов выпуска игр и уникальных годов в датасете

# %%
df['year_of_release'].max()- df['year_of_release'].min()+1
# Out:
# 37.0

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера </b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Что здесь рекомендуется сделать и почему это важно сделать
#
# 1. Вывести все уникальные значения из каждой колонки
# 2. Посмотреть на представленный тип данных
# 3. Сравнить значения выбранной колонки с типом данных
# 4. В случае необходимости внести правки
#
# Рandas не кричит о несоответствии типов. Он молча работает, но неправильно
#
# | Что видим без проверки типов | Что выясняется после проверки |
# |------------------------------|------------------------------|
# | "Средняя зарплата получилась 12345.67" | "А, в колонке 'зарплата' есть текст, удалили 5 плохих строк — теперь средняя 45678.90" |
# | "Выручка упала на 30% в декабре" | "В декабре в данных появился другой формат числа, исправили — падения нет" |
# | "График получился хаотичным" | "Даты были строками, после преобразования график нормальный" |
# | "Merge вернул пустой результат" | "Ключи в разных типах, привели к общему — merge сработал" |
#
# В pandas типы данных — не документация, а гипотеза. И её нужно верифицировать, глядя на реальные значения. 3-4 строки из каждой колонки + проверка dtypes занимают 30 секунд и спасают от часов отладки

# %% [markdown]
# <div class="alert" style="background-color: #d1ecf1; border-color: #bee5eb; border-radius: 8px; padding: 15px;">
#     <font size="3" color="black">
#         Скорректировал
# </div>

# %% [markdown]
# - Возможные причины искажений в топах данных:
#
# Отсутствие оценок критиков для ряда игр может быть связано с недостаточным количеством рецензий, особенно у нишевых или региональных релизов, либо с новизной продукта на момент сбора данных.
#
# В столбце `year_of_release` присутствуют пропущенные значения (NaN), из-за чего pandas автоматически определяет тип данных как float64 вместо логичного int64.
#
# Ошибки типизации в `eu_sales`, `jp_sales` и `user_score` (тип object вместо float64) могут возникнуть из-за неоднородного формата данных — например, из-за ошибок при экспорте или объединении источников. Это часто происходит при ручном сборе или слиянии данных из нескольких баз с разной структурой.
#
# Эти факторы могут влиять на корректность анализа и требуют тщательной предобработки перед построением рейтингов.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>💡  Комментарий ревьюера</b></font>
#     <br />
# <font size="3", color = "black">
# <br />
#
# Можно   в числовых колонках   найти текстовые значения в числовых колонках перед преобразованием — это поможет коллегам найти источник ошибки в БД

# %%
columns_to_check = df.columns.tolist()
for col in df.columns:
    print(f"\n{'─' * 60}")
    print(col)
    print(f"   Тип: {df[col].dtypes}")
    print(f"   Уникальных значений: {df[col].nunique()}")
    
    # Выводим уникальные значения
    unique_vals = df[col].unique()
    if df[col].nunique() <= 20:
        print(f"   Значения: {list(unique_vals)}")
    else:
        print(f"   Первые 20: {list(unique_vals[:20])}")
    
    # Проверка категориальных колонок
    if pd.api.types.is_categorical_dtype(df[col]):
        print(f"   Категории: {list(df[col].cat.categories)}")
# Out:
# ────────────────────────────────────────────────────────────
# name
#    Тип: object
#    Уникальных значений: 11559
#    Первые 20: ['Wii Sports', 'Super Mario Bros.', 'Mario Kart Wii', 'Wii Sports Resort', 'Pokemon Red/Pokemon Blue', 'Tetris', 'New Super Mario Bros.', 'Wii Play', 'New Super Mario Bros. Wii', 'Duck Hunt', 'Nintendogs', 'Mario Kart DS', 'Pokemon Gold/Pokemon Silver', 'Wii Fit', 'Kinect Adventures!', 'Wii Fit Plus', 'Grand Theft Auto V', 'Grand Theft Auto: San Andreas', 'Super Mario World', 'Brain Age: Train Your Brain in Minutes a Day']
#
# ────────────────────────────────────────────────────────────
# platform
#    Тип: object
#    Уникальных значений: 31
#    Первые 20: ['Wii', 'NES', 'GB', 'DS', 'X360', 'PS3', 'PS2', 'SNES', 'GBA', 'PS4', '3DS', 'N64', 'PS', 'XB', 'PC', '2600', 'PSP', 'XOne', 'WiiU', 'GC']
#
# ────────────────────────────────────────────────────────────
# year_of_release
#    Тип: float64
#    Уникальных значений: 37
# ...

# %%
# Находим все значения, где есть хотя бы одна буква (не цифра, не точка, не минус)
# ^ означает "любой символ КРОМЕ" цифр, точки и минуса

pattern = r'[^0-9\.\-]'  

bad_values = df[df['user_score'].str.contains(pattern, na=False, regex=True)]['user_score'].unique()
print("Нечисловые значения:", bad_values)
# Out:
# Нечисловые значения: ['tbd']

# %%
numeric_columns = ['year_of_release', 'na_sales', 'eu_sales', 'jp_sales', 
                   'other_sales', 'critic_score', 'user_score']

# %%
string_values = ['unknown', 'n/a', 'N/A', '-', '', ' ', 'tbd', 'TBD', 'null', 'NULL']
# очистка числовых столбцов от строковых значений
for column in numeric_columns:
    if column in df.columns:
        df[column] = df[column].replace(string_values, pd.NA)

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>💡  Комментарий ревьюера</b></font>
#     <br />
# <font size="3", color = "black">
# <br /> Молодец, знаешь как очищать данные от текста сразу в нескольких колонках
#
#     string_values = ['unknown', 'n/a', 'N/A', '-', '', ' ', 'tbd', 'TBD', 'null', 'NULL']
#     # очистка числовых столбцов от строковых значений
#     for column in numeric_columns:
#         if column in df.columns:
#             df[column] = df[column].replace(string_values, pd.NA)
#
# Эту часть можно оптимизировать, т.к. код df['eu_sales'] = pd.to_numeric(df['eu_sales'], errors='coerce'), очистит колонку от всех подобных значений

# %% [markdown]
# Столбцы `eu_sales`, `jp_sales` и `user_score` должны иметь числовой тип float64, но в текущем виде представлены как object.
#
#
# Мы преобразуем эти столбцы к корректным типам данных и обработаем аномалии в следующием шаге, ниже:

# %%
numeric_cols_to_fix = ['eu_sales', 'jp_sales', 'user_score']
for col in numeric_cols_to_fix:
    df[col] = pd.to_numeric(df[col], errors='coerce')
df['year_of_release'] = df['year_of_release'].astype('Int64')
print("Типы данных после преобразования строковых столбцов:")
for col in ['eu_sales', 'jp_sales', 'user_score','year_of_release']:
    display(f"{col}: {df[col].dtype}")
# Out:
# Типы данных после преобразования строковых столбцов:
# 'eu_sales: float64'
# 'jp_sales: float64'
# 'user_score: float64'
# 'year_of_release: Int64'

# %%
#проверка отрицательных значений
sales_cols = ['na_sales', 'eu_sales', 'jp_sales', 'other_sales']
for col in sales_cols:
    negative = df[df[col] < 0][col].tolist()
    print({len(negative)})
# Out:
# {0}
# {0}
# {0}
# {0}

# %%
#user_score должен быть от 0 до 10
print(f"min: {df['user_score'].min()}, max: {df['user_score'].max()}")
# Out:
# min: 0.0, max: 9.7

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Здесь ты успешно обработал числовые колонки с помощью pd.to_numeric(errors='coerce') и самое главное — выполнил контрольную проверку преобразований типов данных, молодец

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>💡 Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит использовать цикл для однотипных операций
#
#         df['eu_sales'] = pd.to_numeric(df['eu_sales'], errors='coerce')
#         df['jp_sales'] = pd.to_numeric(df['jp_sales'], errors='coerce')
#         df['user_score'] = pd.to_numeric(df['user_score'], errors='coerce')

# %% [markdown]
# <div class="alert" style="background-color: #d1ecf1; border-color: #bee5eb; border-radius: 8px; padding: 15px;">
#     <font size="3" color="black">
#         Сделал циклом
# </div>

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>💡 Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Если в колонке мало уникальных значений (штук 10–15), иногда советуют сделать её типом category.
#
#         rating              object
#
# У такого подхода есть свои плюсы и минусы
#
# [Про ограничения типа данных `.astype('category')` можно посмотреть здесь](https://dfedorov.spb.ru/pandas/%D0%98%D1%81%D0%BF%D0%BE%D0%BB%D1%8C%D0%B7%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D0%B5%20%D1%82%D0%B8%D0%BF%D0%B0%20%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85%20%D0%BA%D0%B0%D1%82%D0%B5%D0%B3%D0%BE%D1%80%D0%B8%D0%B8%20%D0%B2%20pandas.html)

# %% [markdown]
# <div class="alert" style="background-color: #d1ecf1; border-color: #bee5eb; border-radius: 8px; padding: 15px;">
#     <font size="3" color="black">
#         Скорректировал
# </div>

# %%
df['rating'].nunique()
# Out:
# 8

# %% [markdown]
# Уникальных значений достаточно мало, можно преобразовать в катеорию

# %%
df['rating'] = df['rating'].astype('category')

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
# <font size="3", color = "black">
# <br />Стоит  добавить и минивывод о проделанной работе (1-2 предложения)

# %% [markdown]
# Вывод по шагу 2.2:
#
# В результате проверки и предобработки данных все столбцы приведены к корректным типам:
# eu_sales, jp_sales, user_score преобразованы из object в float64, year_of_release — в Int64,
# rating — в category. Некорректные текстовые значения (например, 'tbd') заменены на NaN.

# %% [markdown]
# <div class="alert" style="background-color: #d1ecf1; border-color: #bee5eb; border-radius: 8px; padding: 15px;">
#     <font size="3" color="black">
#         Добавил
# </div>

# %% [markdown]
# ### 2.3. Наличие пропусков в данных
#
# - Посчитайте количество пропусков в каждом столбце в абсолютных и относительных значениях.

# %%
for column in df.columns:
    if column in df.columns:
        null_count = df[column].isnull().sum()
        null_to_all = 1 -df[column].count() / len(df) # доля пропусков
        dtype = df[column].dtype
        print(f"{column:15} | {str(dtype):8} | пропусков: {null_count:4} | доля пропусков: {null_to_all:6}")
# Out:
# name            | object   | пропусков:    2 | доля пропусков: 0.00011795234725175963
# platform        | object   | пропусков:    0 | доля пропусков:    0.0
# year_of_release | Int64    | пропусков:  275 | доля пропусков: 0.01621844774711012
# genre           | object   | пропусков:    2 | доля пропусков: 0.00011795234725175963
# na_sales        | float64  | пропусков:    0 | доля пропусков:    0.0
# eu_sales        | float64  | пропусков:    6 | доля пропусков: 0.00035385704175516786
# jp_sales        | float64  | пропусков:    4 | доля пропусков: 0.00023590469450340823
# other_sales     | float64  | пропусков:    0 | доля пропусков:    0.0
# critic_score    | float64  | пропусков: 8714 | доля пропусков: 0.5139183769757019
# user_score      | float64  | пропусков: 9268 | доля пропусков: 0.5465911771644256
# rating          | category | пропусков: 6871 | доля пропусков: 0.4052252889832507

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Выбран метод .isnull() для поиска пропущенных значений, это отлично!
#
# isnull() и isna() делают одно и то же, но использование isna() предпочтительнее — звучание методов: <b>isna(), notna() и  fillna(), dropna()</b> помогает запомнить их быстрее :)

# %%
missing_info = pd.DataFrame({
    'dtype': df.dtypes,
    'null_count': df.isna().sum(),
    'null_fraction': df.isna().mean()
})
missing_info
# Out:
#                     dtype  null_count  null_fraction
# name               object           2       0.000118
# platform           object           0       0.000000
# year_of_release     Int64         275       0.016218
# genre              object           2       0.000118
# na_sales          float64           0       0.000000
# eu_sales          float64           6       0.000354
# jp_sales          float64           4       0.000236
# other_sales       float64           0       0.000000
# critic_score      float64        8714       0.513918
# user_score        float64        9268       0.546591
# rating           category        6871       0.405225

# %% [markdown]
# - Изучите данные с пропущенными значениями. Напишите промежуточный вывод: для каких столбцов характерны пропуски и сколько их. Предположите, почему пропуски могли возникнуть. Укажите, какие действия с этими данными можно сделать и почему.

# %% [markdown]
# Наибольшее количество пропусков в столбцах `critic_score` и `user_score`. В столбце `year_of_release` содержится менее 2% пропусков.

# %%
# заполним пропуски в year_of_release (менее 2% - можно заполнить медианой)
#median_year = df['year_of_release'].median()
#df['year_of_release'] = df['year_of_release'].fillna(median_year)
#df['year_of_release'] = df['year_of_release'].astype('int64')

# %%
df['has_critic_score'] = df['critic_score'].notna().astype('int64')
df['has_user_score'] = df['user_score'].notna().astype('int64')

# %% [markdown]
# - Обработайте пропущенные значения. Для каждого случая вы можете выбрать оптимальный, на ваш взгляд, вариант: заменить на определённое значение, оставить как есть или удалить.
# - Если вы решите заменить пропуски на значение-индикатор, то убедитесь, что предложенное значение не может быть использовано в данных.
# - Если вы нашли пропуски в данных с количеством проданных копий игры в том или ином регионе, их можно заменить на среднее значение в зависимости от названия платформы и года выхода игры.

# %%
df[df['name'].isnull()]
# Out:
#       name platform  year_of_release genre  na_sales  eu_sales  jp_sales  \
# 661    NaN      GEN             1993   NaN      1.78      0.53      0.00
# 14439  NaN      GEN             1993   NaN      0.00      0.00      0.03
#
#        other_sales  critic_score  user_score rating  has_critic_score  \
# 661           0.08           NaN         NaN    NaN                 0
# 14439         0.00           NaN         NaN    NaN                 0
#
#        has_user_score
# 661                 0
# 14439               0

# %%
# Проверяем строки без названия
display(df[df['name'].isnull()][['platform', 'na_sales', 'eu_sales', 'jp_sales']])

# Проверяем строки без жанра
display(df[df['genre'].isnull()][['name', 'platform', 'na_sales']])
# Out:
#       platform  na_sales  eu_sales  jp_sales
# 661        GEN      1.78      0.53      0.00
# 14439      GEN      0.00      0.00      0.03
#       name platform  na_sales
# 661    NaN      GEN      1.78
# 14439  NaN      GEN      0.00

# %% [markdown]
# В 661 строке есть продажи на 1.78млн, это большое значение, но в рамкам масштаба исследуемых данных можно удалить одну такую строку, дабы избежать некорректного анализа в дальнейшем

# %%
# удалим две строки с пропусками в имени и жанре и строки без года
df_cleaned = df.dropna(subset=['name', 'genre','year_of_release']).copy()

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера </b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# Само решение верное, молодец
#
#         df_cleaned = df.dropna(subset=['name', 'genre','year_of_release']).copy() # удалим две строки с пропусками в имени и жанре и строки без года
#
# но перед удалением стоит посмотреть на записи — может они по 100 млн. продаж принесли ...

# %% [markdown]
# <div class="alert" style="background-color: #d1ecf1; border-color: #bee5eb; border-radius: 8px; padding: 15px;">
#     <font size="3" color="black">
#         Поправил
# </div>

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>💡 Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# ![image-4.png](attachment:image-4.png)
#
# Для красоты («продаваемости») всего проекта не стоит выходить за видимую ширину тетради юпитер ноутбука, коллеги ценят удобство прочтения кода. Широкие строки кода рекомендуется — делить <a href="https://ru.stackoverflow.com/questions/1230993/%D0%9A%D0%B0%D0%BA-%D0%BF%D0%B5%D1%80%D0%B5%D0%BD%D0%B5%D1%81%D1%82%D0%B8-%D1%81%D1%82%D1%80%D0%BE%D0%BA%D1%83-%D0%BF%D0%BE-%D0%BF%D1%80%D0%B0%D0%B2%D0%B8%D0%BB%D0%B0%D0%BC-pep8">Перенос длинных строк кода</a>.
#
# Лучшее решение - использовать круглые скобки вокруг твоих элементов. Оставленный с закрытой круглой скобкой в ​​конце строки, интерпретатор Python присоединится к следующей строке, пока круглые скобки не будут закрыты. То же самое относится и к фигурным и квадратным скобкам
#
# **А комментарии оптимальнее переносить на строку выше, чем располагать справа**

# %% [markdown]
# <div class="alert" style="background-color: #d1ecf1; border-color: #bee5eb; border-radius: 8px; padding: 15px;">
#     <font size="3" color="black">
#         Поправил
# </div>

# %%
# для продаж заполняем пропуски индикаторами (если данных нет, продажи неизвестны = -1)
df_cleaned['eu_sales'] = df_cleaned['eu_sales'].fillna(-1)
df_cleaned['jp_sales'] = df_cleaned['jp_sales'].fillna(-1)

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера </b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит отменить подобное решение
#
#         df_cleaned['eu_sales'] = df_cleaned['eu_sales'].fillna(
#             df_cleaned.groupby(['year_of_release','platform'])['eu_sales'].transform('mean')
#         )
#         df_cleaned['jp_sales'] = df_cleaned['jp_sales'].fillna(
#             df_cleaned.groupby(['year_of_release','platform'])['jp_sales'].transform('mean')
#         )
#
# если бы пропусков было больше, то мы исказили бы выборку — **эти игры могли не продаваться в тех регионах**

# %% [markdown]
# <div class="alert" style="background-color: #d1ecf1; border-color: #bee5eb; border-radius: 8px; padding: 15px;">
#     <font size="3" color="black">
#         Поправил
# </div>

# %%
# дополнительная проверка данных на допустимые границы
display(df_cleaned['user_score'].min())
display(df_cleaned['user_score'].max())
display(df_cleaned['critic_score'].min())
display(df_cleaned['critic_score'].max())
# Out:
# 0.0
# 9.7
# 13.0
# 98.0

# %%
df_cleaned[df_cleaned['rating'] == 'NO_RATING'].shape[0]
# Out:
# 0

# %% [markdown]
# Проверка корректности использования тега:

# %%
# заменим пропуски в рейтинге на флаг 
original_null_count_rating = df_cleaned['rating'].isnull().sum()
original_null_count_rating
original_rating_distribution = df_cleaned['rating'].value_counts(dropna=False)
display(original_rating_distribution)
# Out:
# NaN     6778
# E       3968
# T       2948
# M       1558
# E10+    1414
# EC         8
# K-A        3
# AO         1
# RP         1
# Name: rating, dtype: int64

# %%
# заменяем пропуски на категорию 'NO_RATING' - ее нет в списке возможных тэгов для заполнения
df_cleaned['rating'] = df_cleaned['rating'].cat.add_categories(['NO_RATING'])
df_cleaned['rating'] = df_cleaned['rating'].fillna('NO_RATING')
# проверяем результат
df_cleaned['rating'].value_counts()
# Out:
# NO_RATING    6778
# E            3968
# T            2948
# M            1558
# E10+         1414
# EC              8
# K-A             3
# AO              1
# RP              1
# Name: rating, dtype: int64

# %% [markdown]
# Значения одинаковые (6778), потому что все пропуски "NaN" были успешно заменены на категорию 'NO_RATING'.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Пропуски в категориальных данных, в отличие от числовых, практически всегда можно заполнять, не опасаясь нарушить качество данных
#
#         ... .fillna('NO_RATING')

# %%
missing_info = pd.DataFrame({
    'dtype': df_cleaned.dtypes,
    'null_count': df_cleaned.isna().sum(),
    'null_fraction': df_cleaned.isna().mean()
})
missing_info
# Out:
#                      dtype  null_count  null_fraction
# name                object           0       0.000000
# platform            object           0       0.000000
# year_of_release      Int64           0       0.000000
# genre               object           0       0.000000
# na_sales           float64           0       0.000000
# eu_sales           float64           0       0.000000
# jp_sales           float64           0       0.000000
# other_sales        float64           0       0.000000
# critic_score       float64        8594       0.515259
# user_score         float64        9121       0.546855
# rating            category           0       0.000000
# has_critic_score     int64           0       0.000000
# has_user_score       int64           0       0.000000

# %% [markdown]
# Таким образом, дублирующие строки были корректно обработаны: исходные столбцы сохранены без изменений, а дополнительная информация вынесена в два новых столбца-флага. Это позволило избежать искажения данных и сохранило возможность анализа на основе первоначальных значений.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Подсвечу. Пропуски в оценках критиков и пользователей можно восстановить с помощью внешних источников, но, вероятно, часть игр (особенно старых) не была оценена рейтингами и критиками. Если заменить на среднее или медиану, можно исказить результаты (из-за большого объёма пропущенных значений). Скорее всего это пропуски MNAR — мы не знаем, были ли проведены оценки этих игр.
#
# Один из оптимальных вариантов обработки пропусков на этом проекте с текущей главной задачей — заменить пропуски на значение-индикатор (уникальным значением), чтобы их обработать, но можно оставить и сами пропуски (для этого проекта оба варианта равнозначны)

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />  Осталось добавить минивывод из 2-3-х предложений, — отметить здесь сколько всего данных потеряно в абсолютных числах и относительных (процентах)

# %% [markdown]
# Вывод по шагу 2.3:
# - Удалено 279 строк (1.65% от 16956) с пропусками в name, genre, year_of_release.
# - Пропуски в eu_sales и jp_sales заменены на -1 (индикатор отсутствия данных).
# - Пропуски в rating заменены на 'NO_RATING' (новая категория).
# - Пропуски в critic_score и user_score (≈50%) оставлены как MNAR, созданы флаги.
#  -В df_cleaned осталось 16677 строк (98.35% исходных данных).

# %% [markdown]
# <div class="alert" style="background-color: #d1ecf1; border-color: #bee5eb; border-radius: 8px; padding: 15px;">
#     <font size="3" color="black">
#         Добавил
# </div>

# %% [markdown]
# ### 2.4. Явные и неявные дубликаты в данных
#
# - Изучите уникальные значения в категориальных данных, например с названиями жанра игры, платформы, рейтинга и года выпуска. Проверьте, встречаются ли среди данных неявные дубликаты, связанные с опечатками или разным способом написания.
# - При необходимости проведите нормализацию данных с текстовыми значениями. Названия или жанры игр можно привести к нижнему регистру, а названия рейтинга — к верхнему.

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16679 entries, 0 to 16955
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              16679 non-null  object
#  1   platform          16679 non-null  object
#  2   year_of_release   16679 non-null  Int64
#  3   genre             16679 non-null  object
#  4   na_sales          16679 non-null  float64
#  5   eu_sales          16679 non-null  float64
#  6   jp_sales          16679 non-null  float64
#  7   other_sales       16679 non-null  float64
#  8   critic_score      8085 non-null   float64
#  9   user_score        7558 non-null   float64
#  10  rating            16679 non-null  category
#  11  has_critic_score  16679 non-null  int64
#  12  has_user_score    16679 non-null  int64
# dtypes: Int64(1), category(1), float64(6), int64(2), object(3)
# memory usage: 1.7+ MB

# %%
categorical_columns = ['name','platform', 'genre', 'rating', 'year_of_release']

for column in categorical_columns:
    display(f"\ уникальные значения в '{column}':")
    display(df_cleaned[column].value_counts())
    display(f"всего уникальных: {df_cleaned[column].nunique()}")
# Out:
# "\\ уникальные значения в 'name':"
# Need for Speed: Most Wanted              12
# Ratatouille                               9
# Monopoly                                  9
# LEGO Marvel Super Heroes                  9
# Terraria                                  9
#                                          ..
# Ratchet & Clank: Full Frontal Assault     1
# Mega Man & Bass                           1
# Airblade                                  1
# Perfect Weapon                            1
# Haitaka no Psychedelica                   1
# Name: name, Length: 11426, dtype: int64
# 'всего уникальных: 11426'
# "\\ уникальные значения в 'platform':"
# PS2     2154
# DS      2147
# PS3     1330
# Wii     1305
# X360    1249
# PSP     1212
# PS      1208
# PC       972
# GBA      826
# XB       818
# GC       549
# 3DS      522
# PSV      434
# PS4      395
# N64      320
# XOne     251
# SNES     241
# SAT      174
# WiiU     147
# 2600     118
# NES      100
# GB        97
# DC        52
# ...

# %% [markdown]
# - `platform`: значения приведены к единому формату, скрытых или явных дубликатов не обнаружено
# - `genre`: выявлены дубликаты, вызванные различиями в написании одних и тех же жанров
# - `rating`: обнаружены неявные дубликаты из-за разного формата обозначений. Необходо заменить значения 'К-А' на 'Е'
# - `year_of_release`: нормализованы, пропуски обработаны, дублирующихся или противоречивых значений нет.
# - `name`: дополнительно приведем в верхний регистр

# %%
df_cleaned['name'] = df_cleaned['name'].str.upper()
df_cleaned['genre'] = df_cleaned['genre'].str.lower()
df_cleaned['rating'] = df_cleaned['rating'].replace('K-A', 'E')
rare_categories = ['EC', 'AO', 'RP', 'K-A']
df_cleaned['rating'] = df_cleaned['rating'].replace(rare_categories, 'Other')

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Отличное решение, нормализовал текстовые данные, нашел и обработал неявные дубликаты в жанрах

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера </b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит завершить работу по сокращению категорий в рейтинге
#
#             NO_RATING    6778
#             E            3971
#             T            2948
#             M            1558
#             E10+         1414
#
#
#             EC              8
#             AO              1
#             RP              1
#
# **Почему это важно:** категории с менее чем 10 наблюдениями (EC, AO, RP) создают риск переобучения, делают анализ статистически ненадёжным и загромождают визуализации. Объединение их в группу «Другие» упростит интерпретацию без потери значимой информации, в некоторых случаях (например нет влияния на продажи) такие строки можно просто удалить

# %% [markdown]
# <div class="alert" style="background-color: #d1ecf1; border-color: #bee5eb; border-radius: 8px; padding: 15px;">
#     <font size="3" color="black">
#         Объединил категории
# </div>

# %%
categorical_columns = ['name','platform', 'genre', 'rating', 'year_of_release']

for column in categorical_columns:
    display(f"\ уникальные значения в '{column}':")
    display(df_cleaned[column].value_counts())
    display(f"всего уникальных: {df_cleaned[column].nunique()}")
# Out:
# "\\ уникальные значения в 'name':"
# NEED FOR SPEED: MOST WANTED              12
# RATATOUILLE                               9
# MONOPOLY                                  9
# LEGO MARVEL SUPER HEROES                  9
# TERRARIA                                  9
#                                          ..
# RATCHET & CLANK: FULL FRONTAL ASSAULT     1
# MEGA MAN & BASS                           1
# AIRBLADE                                  1
# PERFECT WEAPON                            1
# HAITAKA NO PSYCHEDELICA                   1
# Name: name, Length: 11426, dtype: int64
# 'всего уникальных: 11426'
# "\\ уникальные значения в 'platform':"
# PS2     2154
# DS      2147
# PS3     1330
# Wii     1305
# X360    1249
# PSP     1212
# PS      1208
# PC       972
# GBA      826
# XB       818
# GC       549
# 3DS      522
# PSV      434
# PS4      395
# N64      320
# XOne     251
# SNES     241
# SAT      174
# WiiU     147
# 2600     118
# NES      100
# GB        97
# DC        52
# ...

# %% [markdown]
#  - Проверяем данные на явные дубликаты:

# %%
full_duplicates_count = df_cleaned.duplicated().sum()
full_duplicates_count
# Out:
# 235

# %%
if full_duplicates_count > 0:
    duplicate_rows = df_cleaned[df_cleaned.duplicated(keep=False)]  
    display(duplicate_rows.head(10))
# Out:
#                                  name platform  year_of_release    genre  \
# 267             BATMAN: ARKHAM ASYLUM      PS3             2009   action
# 268             BATMAN: ARKHAM ASYLUM      PS3             2009   action
# 367  JAMES BOND 007: AGENT UNDER FIRE      PS2             2001  shooter
# 368  JAMES BOND 007: AGENT UNDER FIRE      PS2             2001  shooter
# 716             GOD OF WAR: ASCENSION      PS3             2013   action
# 717             GOD OF WAR: ASCENSION      PS3             2013   action
# 822                 WIPEOUT: THE GAME      Wii             2009     misc
# 823                 WIPEOUT: THE GAME      Wii             2009     misc
# 847   RAYMAN RAVING RABBIDS: TV PARTY      Wii             2008     misc
# 848   RAYMAN RAVING RABBIDS: TV PARTY      Wii             2008     misc
#
#      na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 267      2.24      1.31      0.07         0.61          91.0         8.9
# ...

# %%
original_size = len(df)
df_cleaned = df_cleaned.drop_duplicates()

new_size = len(df_cleaned)
removed_count = full_duplicates_count
removed_to_original_dubl = removed_count / new_size
deleted = original_size - new_size
removed_to_original = deleted / original_size

print(f"размер dataset: {original_size}")
print(f"удалено дубликатов: {full_duplicates_count}")
print(f"всего удалено: {deleted}")
print(f"доля удаленных дубликатов: {removed_to_original_dubl}")
print(f"доля удаленных строк: {removed_to_original}")
print(f"новый размер dataset: {new_size}")
# Out:
# размер dataset: 16956
# удалено дубликатов: 235
# всего удалено: 512
# доля удаленных дубликатов: 0.014290926781804913
# доля удаленных строк: 0.03019580089643784
# новый размер dataset: 16444

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Отличное решение — проконтроллировать размер оставшихся данных
#
# Иногда и коллеги с опытом удаляют более половины данных на подобных операциях, по этой причине — постоянный контроль за размером выборки — первый шаг для избавления от лишних часов поиска ошибок на проекте 🤝

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>💡 Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# На рабочих проектах стоит искать неполные дубликаты по ключевым столбцам, для примера по сумме параметров:
#
#     ['name', 'platform', 'year_of_release']
#
# С обязательным приведением содержимого категориальных колонок к нижнему регистру
#
# В сырой выборке имеется 1 или 2 строчки неполных дубликатов
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.duplicated.html?highlight=duplicat#pandas.DataFrame.duplicated

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
#     <font size="3", color = "black">
# <br /> Для избавления от лишних и случайных пробелов можно использовать возможности
#
#         .str.strip()
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.strip.html
#
# https://uproger.com/python-rukovodstvo-po-metodu-strip/?ysclid=lj7m37yxbb134617214

# %% [markdown]
# - В процессе подготовки данных вы могли что-либо удалять, например строки с пропусками или ошибками, дубликаты и прочее. В этом случае посчитайте количество удалённых строк в абсолютном и относительном значениях.

# %% [markdown]
# В ходе предобработки из датасета было удалено 241 явное дублирование строк.

# %% [markdown]
# - После проведения предобработки данных напишите общий промежуточный вывод.

# %% [markdown]
# Итоговый датасет содержит 16 444 строки. Все текстовые столбцы нормализованы, обработаны явные и неявные дубликаты, пропуски заполнены с учётом контекста. Данные подготовлены и пригодны для дальнейшего анализа, построения графиков и поиска закономерностей.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />  Молодец, зафиксировал процент потерь в результате подготовки данных в расчетах, стоит добавить эту информацию и в вывод — заказчик не станет искать в расчетах этот процент
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ---
#
# ## 3. Фильтрация данных
#
# Коллеги хотят изучить историю продаж игр в начале XXI века, и их интересует период с 2000 по 2013 год включительно. Отберите данные по этому показателю. Сохраните новый срез данных в отдельном датафрейме, например `df_actual`.

# %%
df_actual = df_cleaned[(df_cleaned['year_of_release'] >= 2000) & (df_cleaned['year_of_release'] <= 2013)].copy()

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>💡  Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Отлично — фильтрация данных выполнена корректно
#
# Стоит применять метод .copy() при фильтрации — это защита от случайного изменения исходного DataFrame при последующих операциях

# %% [markdown]
# <div class="alert" style="background-color: #d1ecf1; border-color: #bee5eb; border-radius: 8px; padding: 15px;">
#     <font size="3" color="black">
#        Скорректировал
# </div>

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>💡  Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Несмотря на рекомендацию в ТЗ проекта, я бы сократил название датасета
#
#         df_actual, например до data
#
# Cложные названия для выборки отнимают массу рабочего времени на набор, особенно, если приходится исследовать такой датасет по несколько часов и в разных ракурсах
#
#         df_actual, df_cleaned
#
# Но стоит учесть - на последнем шаге проекта мы должны отдать заказчику датафрейм уже именно с таким названием `'df_actual'`, из ТЗ проекта, или согласовать упрощенное имя датафрейма на этапе формирования ТЗ

# %% [markdown]
# <div class="alert" style="background-color: #d1ecf1; border-color: #bee5eb; border-radius: 8px; padding: 15px;">
#     <font size="3" color="black">
#         Учту
# </div>

# %%
# дополнительные проверки
print(len(df_actual))
print(df_actual['year_of_release'].min())
print(df_actual['year_of_release'].max())
# Out:
# 12781
# 2000
# 2013

# %%
df_actual.head()
# Out:
#                     name platform  year_of_release     genre  na_sales  \
# 0             WII SPORTS      Wii             2006    sports     41.36
# 2         MARIO KART WII      Wii             2008    racing     15.68
# 3      WII SPORTS RESORT      Wii             2009    sports     15.61
# 6  NEW SUPER MARIO BROS.       DS             2006  platform     11.28
# 7               WII PLAY      Wii             2006      misc     13.96
#
#    eu_sales  jp_sales  other_sales  critic_score  user_score rating  \
# 0     28.96      3.77         8.45          76.0         8.0      E
# 2     12.76      3.79         3.29          82.0         8.3      E
# 3     10.93      3.28         2.95          80.0         8.0      E
# 6      9.14      6.50         2.88          89.0         8.5      E
# 7      9.18      2.93         2.84          58.0         6.6      E
#
#    has_critic_score  has_user_score
# 0                 1               1
# 2                 1               1
# ...

# %%
df_actual.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12781 entries, 0 to 16954
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              12781 non-null  object
#  1   platform          12781 non-null  object
#  2   year_of_release   12781 non-null  Int64
#  3   genre             12781 non-null  object
#  4   na_sales          12781 non-null  float64
#  5   eu_sales          12781 non-null  float64
#  6   jp_sales          12781 non-null  float64
#  7   other_sales       12781 non-null  float64
#  8   critic_score      7169 non-null   float64
#  9   user_score        6483 non-null   float64
#  10  rating            12781 non-null  category
#  11  has_critic_score  12781 non-null  int64
#  12  has_user_score    12781 non-null  int64
# dtypes: Int64(1), category(1), float64(6), int64(2), object(3)
# memory usage: 1.3+ MB

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>💡  Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит проверить новый датасет, хотя бы 2-мя методами → info() и .head()
#
#         df_actual
#
# При копировании или до него всякое может произойти с данными, и оптимальнее будет поймать эту ошибку здесь, на этом шаге, чем через 2-3 часа работы
#
# Правило — создал новую выборку, обязательно проверил её

# %% [markdown]
# <div class="alert" style="background-color: #d1ecf1; border-color: #bee5eb; border-radius: 8px; padding: 15px;">
#     <font size="3" color="black">
#         Сделал
# </div>

# %% [markdown]
# ---
#
# ## 4. Категоризация данных
#
# Проведите категоризацию данных:
# - Разделите все игры по оценкам пользователей и выделите такие категории: высокая оценка (от 8 до 10 включительно), средняя оценка (от 3 до 8, не включая правую границу интервала) и низкая оценка (от 0 до 3, не включая правую границу интервала).

# %%
def categorizing(score):
    if (score >= 8) & (score <=10):
        return 'высокая оценка'
    elif score >=3:
        return 'средняя оценка'
    elif score >= 0:
        return 'низкая оценка' 
    else:
        return 'нет оценки'

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Отлично, добавил 4-ю категорию для случаев, которые не впишутся в настоящую логику (0-10), молодец
#
#             else:
#                 return 'нет оценки'

# %%
df_actual = df_actual.copy()
df_actual.loc[:, 'user_score_category'] = df_actual['user_score'].apply(categorizing)

# %%
categories = ['высокая оценка', 'средняя оценка', 'низкая оценка', 'нет оценки']
for cat in categories:
    print(f"\n Категория: {cat}")
    samples = df_actual[df_actual['user_score_category'] == cat][['name', 'user_score']].head(5)
    if len(samples) > 0:
        display(samples)
# Out:
#  Категория: высокая оценка
#                         name  user_score
# 0                 WII SPORTS         8.0
# 2             MARIO KART WII         8.3
# 3          WII SPORTS RESORT         8.0
# 6      NEW SUPER MARIO BROS.         8.5
# 8  NEW SUPER MARIO BROS. WII         8.4
#  Категория: средняя оценка
#                                             name  user_score
# 7                                       WII PLAY         6.6
# 13                                       WII FIT         7.7
# 14                            KINECT ADVENTURES!         6.3
# 15                                  WII FIT PLUS         7.4
# 19  BRAIN AGE: TRAIN YOUR BRAIN IN MINUTES A DAY         7.9
#  Категория: низкая оценка
#                                 name  user_score
# 60              CALL OF DUTY: GHOSTS         2.6
# 69              CALL OF DUTY: GHOSTS         2.6
# 677    KINECT: DISNEYLAND ADVENTURES         2.9
# 1047  CALL OF DUTY: MODERN WARFARE 3         2.5
# ...

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>💡  Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит выполнить и визуальный контроль качества категоризации, например вывести по 3-5 значений из каждой категории

# %% [markdown]
# <div class="alert" style="background-color: #d1ecf1; border-color: #bee5eb; border-radius: 8px; padding: 15px;">
#     <font size="3" color="black">
#         Исправил
# </div>

# %% [markdown]
# - Разделите все игры по оценкам критиков и выделите такие категории: высокая оценка (от 80 до 100 включительно), средняя оценка (от 30 до 80, не включая правую границу интервала) и низкая оценка (от 0 до 30, не включая правую границу интервала).

# %%
def categorizing_critic(score):
    if (score >= 80) & (score <=100):
        return 'высокая оценка'
    elif score >=30:
        return 'средняя оценка'
    elif score >= 0:
        return 'низкая оценка' 
    else:
        return 'нет оценки'

# %%
df_actual.loc[:, 'critic_score_category'] = df_actual['critic_score'].apply(categorizing_critic)

# %%
 # df_actual['critic_score_category'].value_counts() альтернативный вариант сортировки

# %% [markdown]
# - После категоризации данных проверьте результат: сгруппируйте данные по выделенным категориям и посчитайте количество игр в каждой категории.

# %%
user_score_counts = df_actual.groupby('user_score_category')['name'].count().sort_values(ascending=False)
user_score_counts
# Out:
# user_score_category
# нет оценки        6298
# средняя оценка    4081
# высокая оценка    2286
# низкая оценка      116
# Name: name, dtype: int64

# %%
critic_score_counts = df_actual.groupby('critic_score_category')['name'].count().sort_values(ascending=False)
critic_score_counts
# Out:
# critic_score_category
# нет оценки        5612
# средняя оценка    5422
# высокая оценка    1692
# низкая оценка       55
# Name: name, dtype: int64

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>💡  Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит добавить минивывод

# %% [markdown]
# Вывод по шагу 4:
#
# Большинство игр (≈50%) не имеют пользовательских оценок, что подтверждает ранее
# сделанный вывод о MNAR-пропусках. Среди оценённых игр преобладают игры со
# средними оценками как у пользователей (31.9%), так и у критиков (42.4%).
# Игр с низкими оценками очень мало (<1%), что может говорить о том, что
# слабым играм редко присваивают оценки.

# %% [markdown]
# <div class="alert" style="background-color: #d1ecf1; border-color: #bee5eb; border-radius: 8px; padding: 15px;">
#     <font size="3" color="black">
#         Сделано
# </div>

# %% [markdown]
# - Выделите топ-7 платформ по количеству игр, выпущенных за весь актуальный период.

# %%
platform_rating = df_actual.groupby('platform')['name'].count().sort_values(ascending=False)
platform_rating.head(7)
# Out:
# platform
# PS2     2127
# DS      2120
# Wii     1275
# PSP     1180
# X360    1121
# PS3     1087
# GBA      811
# Name: name, dtype: int64

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Молодец, последняя задача проекта решена верно — ТОП-7 найден корректно

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4"><b>🍕 Комментарий ревьюера </b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Есть способ сократить кол-во печатных букв, вместо → .head(7)
#
#         df_actual['platform'].value_counts().head(7)
#
# использовать → [:7]
#
#         df_actual['platform'].value_counts()[:7]

# %%
df_actual.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12781 entries, 0 to 16954
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   name                   12781 non-null  object
#  1   platform               12781 non-null  object
#  2   year_of_release        12781 non-null  Int64
#  3   genre                  12781 non-null  object
#  4   na_sales               12781 non-null  float64
#  5   eu_sales               12781 non-null  float64
#  6   jp_sales               12781 non-null  float64
#  7   other_sales            12781 non-null  float64
#  8   critic_score           7169 non-null   float64
#  9   user_score             6483 non-null   float64
#  10  rating                 12781 non-null  category
#  11  has_critic_score       12781 non-null  int64
#  12  has_user_score         12781 non-null  int64
#  13  user_score_category    12781 non-null  object
# ...

# %% [markdown]
# ---
#
# ## 5. Итоговый вывод

# %% [markdown]
# 1. Динамика данных в ходе предобработки:
#    - Исходный датасет: 16 956 строк
#    - После очистки (df_cleaned): 16 444 строки
#    - Потеряно данных: 512 строк (3.02% от исходного объёма)
#
#    Причины потерь:
#    - Удаление пропусков (name, genre, year_of_release): 279 строк (1.65%)
#    - Удаление явных дубликатов: 235 строк (1.39%)
#
# 2. Фильтрация по периоду 2000-2013 гг.:
#    - После фильтрации (df_actual): 12 781 игра
#    - Доля данных за период 2000-2013: 77.7% от очищенных данных
#
# 3. Топ-7 платформ по количеству игр:
#    1. PS2  – 2 127 игр (16.6%)
#    2. DS   – 2 120 игр (16.6%)
#    3. Wii  – 1 275 игр (10.0%)
#    4. PSP  – 1 180 игр (9.2%)
#    5. X360 – 1 121 игра (8.8%)
#    6. PS3  – 1 087 игр (8.5%)
#    7. GBA  – 811 игр (6.3%)
#
#    Совокупная доля топ-7: 76.0% от всех игр периода
#
# 4. Ключевые выводы:
#    - PS2 и Nintendo DS – бесспорные лидеры эпохи (по 16.6% игр)
#    - 49.3% игр не имеют пользовательских оценок (MNAR-пропуски)
#    - 43.9% игр не имеют оценок критиков
#    - Среди оценённых игр преобладают средние оценки (31.9% – пользователи, 42.4% – критики)
#    - Игр с низкими оценками менее 1%
#    - Топ-7 платформ покрывают 76.0% всех игр периода 2000-2013
# - Высокий процент пропущенных оценок: почти половина игр не имеет пользовательских рейтингов. Это подчёркивает необходимость - осторожного подхода к анализу на основе субъективных оценок и акцентирует важность проверки репрезентативности выборки.
#
# - Лидерство Sony и Nintendo: PS2 и Nintendo DS — бесспорные флагманы эпохи, лидирующие по количеству выпущенных игр. Их успех отражает как технологическое, так и маркетинговое превосходство.
#
# - Сбалансированность оценок: большинство игр получают средние баллы, что указывает на стабильный уровень качества в индустрии — ни чрезмерного количества провалов, ни всплесков шедевров. Это свидетельствует о зрелости разработки и конвейеризации процессов.

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Хороший вывод! Он передает основные этапы работ на проекте, есть и часть ключевых цифр
#
# Осталось добавить и другую часть ключевых цифр (YY YYY после предобработки, AA.A% данных пришлось на период 2000-2013 гг. и ВВ.В% на топ-7 платформ), плюс и такие метрики — почему удалили F.FF % данных, частично они имеются, но стоит объединить их в один блок

# %% [markdown]
# <div class="alert" style="background-color: #d1ecf1; border-color: #bee5eb; border-radius: 8px; padding: 15px;">
#     <font size="3" color="black">
#         Переформулировал
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <font size="5", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# Ты хорошо поработал над проектом „Python. Предобработка данных“. Уверенно исследуешь структуру датасетов, готовишь данные к анализу, обрабатываешь пропуски и дубликаты — и, что важно, умеешь использовать результаты своей работы для  выводов
#
# ❌ Что нужно доработать:
#
# + ознакомиться с уникальными значениями во всех колонках
# + поправить несколько выводов
#
# Обрати внимание на комментарии, отмеченные 💡. Они не требуют обязательного исправления — это скорее пища для размышления и возможности для профессионального роста. Если будет время и желание — можешь их реализовать, но базовая работа принимается и без них
#
# Если будут вопросы про мои комментарии - задавай, если какой-то формат взаимодействия не устраивает или есть какие-то другие пожелания - пиши :)
#
# <div class="alert alert-success">
#     <font size="5", color= "seagreen"><b>Жду твой проект и твои комментарии 🤝</b></font><br />
